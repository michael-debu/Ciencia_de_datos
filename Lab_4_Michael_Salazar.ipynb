# %% [markdown]
# ## Laboratorio: Análisis de Datos con Python

# %% [markdown]
# ### Michael Salazar

# %% [markdown]
# #### Para los ejercicios siguiente genere el código que considere para resolver el problema que se le plantea.
# #### Parte I
#
# ##### 1) ¿Cuál es el tamaño en bytes de un array de 1000 elementos de tipo booleano?

# %%
# cantidad de elementos
n = 1000

# cada booleano ocupa 1 byte
size = 1

# multiplicamos
resultado = n * size

print("El tamaño es :", resultado, "bytes")
# Out:
# El tamaño es : 1000 bytes

# %% [markdown]
# ##### 2) Cree un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla.

# %%
# Lista vacía
numeros = []

# Revisión del 1 a 100 
for i in range(1, 101):
    # si el número es par
    if i % 2 == 0:
        numeros.append(i)

# Ordenar de mayor a menor
numeros.reverse()

# muestro los últimos 10
print(numeros[-10:])
# Out:
# [20, 18, 16, 14, 12, 10, 8, 6, 4, 2]

# %% [markdown]
# ##### 3) Dado el array
# ##### 2 4 5 6
# ##### 0 3 7 4
# ##### 8 8 5 2
# ##### 1 5 6 1
# ##### Seleccione con una instrucción el subarray de elementos
# ##### 0 3 7 4
# #### Después, seleccione el subarray de elementos
# ##### 2 5
# ##### 8 5

# %%
# Definición de la matriz
arr = [
    [2, 4, 5, 6],
    [0, 3, 7, 4],
    [8, 8, 5, 2],
    [1, 5, 6, 1]
]

# seleccion de la fila 0 3 7 4 , recordando que se empieza desde 0

print(arr[1])

# seleccionar los subarrays de los elementos 2 5 y 8 5 
print([
    [arr[0][0], arr[0][2]],
    [arr[2][0], arr[2][2]]
])
# Out:
# [0, 3, 7, 4]
# [[2, 5], [8, 5]]

# %% [markdown]
# ##### 4) Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
# Definimos los arrrays 

a = [1, 4, 2, 7]
b = [1, 3, 2, 9]

# Guardar los resultados 
res = []

for i in range(4):
    res.append(a[i] - b[i])

# Media aritmética de la diferencia (a-b).
media = (res[0] + res[1] + res[2] + res[3]) / 4

print(media)
# Out:
# -0.25

# %% [markdown]
# ##### 5) Tengo valores de cordenadas (x, y) en las columnas del array
# ##### 1.33 4.5
# ##### 30.0 10.7
# ##### 70.2 0.5
# ##### Agregue a este array las coordenadas (37.1, -3.6).Muestre en pantalla las dimensiones del nuevo array.

# %%
# Array con las coordenadas
arr = [
    [1.33, 4.5],
    [30.0, 10.7],
    [70.2, 0.5]
]

# La nueva coordenada en el array
arr.append([37.1, -3.6])

# Mostrar el array nuevo
print(arr)

# Dimensiones nuevas 
filas = len(arr)
columnas = len(arr[0])

print("Dimensiones:", filas, "*", columnas)
# Out:
# [[1.33, 4.5], [30.0, 10.7], [70.2, 0.5], [37.1, -3.6]]
# Dimensiones: 4 * 2

# %% [markdown]
# ##### 6) Copie el array del ejercicio anterior. Traspóngalo. Agregue ahora dos nuevos pares de coordenadas: (10.8, 3.0) y (35.8, 12.0).

# %%
# array del ejercicio anterior

arr = [
    [1.33, 4.5],
    [30.0, 10.7],
    [70.2, 0.5],
    [37.1, -3.6]
]

# transponer
transponer = [
    [arr[0][0], arr[1][0], arr[2][0], arr[3][0]],
    [arr[0][1], arr[1][1], arr[2][1], arr[3][1]]
]

# nuevas coordenadas

arr.append([10.8, 3.0])
arr.append([35.8, 12.0])

print("Transponer:")
print(transponer)

print("Nuevo array:")
print(arr)
# Out:
# Transponer:
# [[1.33, 30.0, 70.2, 37.1], [4.5, 10.7, 0.5, -3.6]]
# Nuevo array:
# [[1.33, 4.5], [30.0, 10.7], [70.2, 0.5], [37.1, -3.6], [10.8, 3.0], [35.8, 12.0]]

# %% [markdown]
# #### Parte II : Exploración y Minería de Datos:

# %% [markdown]
# ##### Con el dataset nucleospoblacion.csv adjunto al laboratorio,  luego responda las siguientes preguntas usando pandas y matplotlib.

# %%
## Import del dataset para poder ser analizado

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("NucleosPoblacion.csv")

print(df.head())
print(df.columns)
# Out:
#    FID  OBJECTID     Texto  Poblacion  CodMun Municipio  CodProvin  \
# 0    0         1   Agüimes    29431.0   35002   Agüimes         35
# 1    1         2   Antigua    10458.0   35003   Antigua         35
# 2    2         3  Arrecife    58156.0   35004  Arrecife         35
# 3    3         4    Arucas    36745.0   35006    Arucas         35
# 4    4         5    Gáldar    24473.0   35009    Gáldar         35
#
#     Provincia          X          Y
# 0  Las Palmas -15.446012  27.900542
# 1  Las Palmas -14.013301  28.418966
# 2  Las Palmas -13.551451  28.960649
# 3  Las Palmas -15.521512  28.117496
# 4  Las Palmas -15.654111  28.143873
# Index(['FID', 'OBJECTID', 'Texto', 'Poblacion', 'CodMun', 'Municipio',
#        'CodProvin', 'Provincia', 'X', 'Y'],
#       dtype='object')

# %% [markdown]
# ##### 1) ¿Cuántos Municipios tienen más de 100000  habitantes?.

# %%
mun = df[df["Poblacion"] > 100000]

print(len(mun))
# Out:
# 62

# %% [markdown]
# ##### 2) Realice una gráfica de barras sobre la polbación de cada ciudad, ordenela de menor a mayo y responda:

# %%
# Se realizo este top 20 para que se pueda realizar mejor el analisis visual de la grafica

# ordenar de mayor a menor
top20 = df.sort_values("Poblacion", ascending=False).head(20)

# gráfica

plt.figure(figsize=(50,10))
plt.bar(top20["Municipio"], top20["Poblacion"], color ="mediumturquoise" )

plt.xticks(rotation=90, size=20)
plt.title("Top 20 ciudades más pobladas", size=30)
plt.show()

# %% [markdown]
# ##### 2a. ¿Cuál es la segunda ciudad más poblada?

# %%
orden = df.sort_values("Poblacion", ascending=False)

print(orden.iloc[1]["Municipio"])
# Out:
# Barcelona

# %% [markdown]
# ##### 2b.) ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas?

# %%
orden = df.sort_values("Poblacion", ascending=False)

lista = list(orden["Municipio"])

print(lista.index("Granada") + 1)
# Out:
# 18

# %% [markdown]
# ##### 3. ¿Cuántos municipios de Extremadura tienen más de 5000 habitantes?.

# %%
ext = df[df["Provincia"] == "Extremadura"]

res = ext[ext["Poblacion"] > 5000]

print(len(res))
# Out:
# 0

# %% [markdown]
# ##### 4. ¿Cuál es el municipio situado más al Norte? (Usar el  valor de la coordenada "Y" que representa la latitud en  grados). Proporcione también la provincia a la que pertenece y su población.

# %%
norte = df.sort_values("Y", ascending=False)

print(norte.iloc[0][["Municipio", "Provincia", "Poblacion"]])
# Out:
# Municipio    Viveiro
# Provincia       Lugo
# Poblacion    16211.0
# Name: 104, dtype: object

# %% [markdown]
# ##### 5. Obtenga la media, mediana, desviación estándar, valor  máximo y valor mínimo de la población de los municipios de la provincia de Granada.

# %%
granada = df[df["Provincia"] == "Granada"]

print("Media:", granada["Poblacion"].mean())
print("Mediana:", granada["Poblacion"].median())
print("Desviación :", round (granada["Poblacion"].std(),2))
print("Máximo :",  granada["Poblacion"].max())
print("Mínimo :", granada["Poblacion"].min())
# Out:
# Media: 30217.85
# Mediana: 17526.0
# Desviación : 50355.49
# Máximo : 239154.0
# Mínimo : 10386.0

# %% [markdown]
# ##### 6. Realice un histograma con la población de los Municipios para cada una de las provincias.

# %%
plt.hist(df["Poblacion"], bins=50, color = "paleturquoise")

plt.xlabel("Población")
plt.ylabel("Cantidad de municipios")
plt.title("Histograma de la población")

plt.show()

# %% [markdown]
# ##### 7) Seleccione al azar cincuenta municipios diferentes de  entre los diponibles en el archivo. Asegúrese de que no  se repitan. ¿Luego calcule el promedio de la población y la desviación estándar de esto 50 municipios?.

# %%
# tomar 50 municipios sin repetir
muestra = df.sample(n=50, replace=False)

# calcular promedio y desviación
print("Promedio:", muestra["Poblacion"].mean())
print("Desviación estándar:", round (muestra["Poblacion"].std(),2))
# Out:
# Promedio: 53104.42
# Desviación estándar: 75163.78

# %% [markdown]
# ##### 8) Dígame los nombres de los Municipios más cercano y más lejano a Madrid. Para ello debe calcular la distancia en  todos ellos y Madrid. No considere a Madrid en el análisis ya que la distancia sería cero

# %%
import math

# Quitar Madrid 
madrid = df[df["Municipio"] == "Madrid"].iloc[0]

# Calcular la distancia 
df["dist"] = ((df["X"] - madrid["X"])**2 + (df["Y"] - madrid["Y"])**2)**0.5

# Quitar Madrid 
df2 = df[df["Municipio"] != "Madrid"]

# Resultados
print("Más cercano:", df2.sort_values("dist").iloc[0]["Municipio"])
print("Más lejano:", df2.sort_values("dist", ascending=False).iloc[0]["Municipio"])
# Out:
# Más cercano: Pozuelo de Alarcón
# Más lejano: Los Llanos de Aridane
